# %% [markdown]
# # Transfermarkt market-value score
#
# Load the latest KBStats player CSV and standard Transfermarkt Bundesliga squad CSV. This notebook assigns the raw integer-Euro `market_value_eur` to `score`, preserves all KBStats player rows, and writes an optimizer-compatible expected-points CSV.
#
# Names are matched accent-, punctuation-, case-, and whitespace-insensitively. When a close name is found, select the correct Transfermarkt player or skip it for score zero. Confirmed choices are saved to the shared `data/reference/player_name_cross_references.csv`.

# %% [markdown]
# ## Create scores

# %%
import sys
from pathlib import Path


def locate_project_root() -> Path:
    starts = []
    notebook_path = globals().get('__vsc_ipynb_file__')
    if isinstance(notebook_path, str) and notebook_path.strip():
        starts.append(Path(notebook_path).expanduser().resolve().parent)
    starts.append(Path.cwd().resolve())
    for start in starts:
        for candidate in (start, *start.parents):
            if (candidate / 'project_paths.py').is_file():
                return candidate
    raise FileNotFoundError('Could not locate project_paths.py. Start Jupyter from the project root.')


PROJECT_ROOT = locate_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from transfermarkt_market_value_score import run_score_creation

result = run_score_creation()
# Out:
# No exact Transfermarkt match for KBStats player: Kim Minjae
#   1. Min-jae Kim (Transfermarkt ID 503482, €20,000,000, similarity 67%)
#   2. Kristijan Jakic (Transfermarkt ID 374954, €6,000,000, similarity 52%)
#   3. Koki Machida (Transfermarkt ID 415035, €6,000,000, similarity 50%)
# C:\kickbase project\transfermarkt_market_value_score.py:381: UserWarning: Ignoring non-standard Transfermarkt squad export: transfermarkt_bundesliga_squads_2026_20260810_171333_team_market_value_p80.csv
#   transfermarkt_input = _select_latest_transfermarkt_csv()
# C:\kickbase project\transfermarkt_market_value_score.py:381: UserWarning: Ignoring non-standard Transfermarkt squad export: transfermarkt_bundesliga_squads_2026_20260810_171333_team_market_value_p90.csv
#   transfermarkt_input = _select_latest_transfermarkt_csv()
# ...
