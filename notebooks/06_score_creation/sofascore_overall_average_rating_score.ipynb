# %% [markdown]
# # SofaScore overall average-rating score
#
# Load the latest KBStats player CSV and latest SofaScore player-average-ratings CSV. This notebook uses the `overall` category as the raw decimal `score`, preserves every KBStats player row, and writes an optimizer-compatible expected-points CSV.
#
# Names are matched accent-, punctuation-, case-, and whitespace-insensitively. When a close name is found, choose the appropriate SofaScore player or skip it for score zero; confirmed choices are retained in the shared `data/reference/player_name_cross_references.csv`.

# %% [markdown]
# ## Create scores

# %%
import sys
from pathlib import Path


def locate_project_root() -> Path:
    starts = []
    notebook_path = globals().get('__vsc_ipynb_file__')
    if isinstance(notebook_path, str) and notebook_path.strip():
        starts.append(Path(notebook_path).expanduser().resolve().parent)
    starts.append(Path.cwd().resolve())
    for start in starts:
        for candidate in (start, *start.parents):
            if (candidate / 'project_paths.py').is_file():
                return candidate
    raise FileNotFoundError('Could not locate project_paths.py. Start Jupyter from the project root.')


PROJECT_ROOT = locate_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from sofascore_average_rating_score import run_score_creation

result = run_score_creation(category='overall')
# Out:
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Dayotchanculle Upamecano' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# No exact SofaScore match for KBStats player: Luca Jaquez
#   1. Lucas Vázquez (SofaScore ID 255239, rating 6.1, similarity 82%)
# Choose a candidate number, or press Enter to skip (score 0):
# No exact SofaScore match for KBStats player: Maximilian Rohr
#   1. Maximilian Beier (SofaScore ID 980628, rating 6.5, similarity 76%)
#   2. Maximilian Wöber (SofaScore ID 794962, rating 6.5, similarity 76%)
# Choose a candidate number, or press Enter to skip (score 0):
# No exact SofaScore match for KBStats player: Victor Boniface
#   1. Victor Okoh Boniface (SofaScore ID 978521, rating 7.6, similarity 88%)
# Choose a candidate number, or press Enter to skip (score 0):  1
# No exact SofaScore match for KBStats player: Aleksa Damjanovic
#   1. Aleksandar Pavlović (SofaScore ID 1142251, rating 7.1, similarity 76%)
# Choose a candidate number, or press Enter to skip (score 0):
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Jan Thielmann' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Ísak Jóhannesson' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Philipp Mwene' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Silvan Dominic Widmer' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Ransford Königsdörffer' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# No exact SofaScore match for KBStats player: Robin Hack
#   1. Robin Hranáč (SofaScore ID 957615, rating 6.1, similarity 80%)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Tjark Scheller' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# Choose a candidate number, or press Enter to skip (score 0):
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Joseph Scally' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Daniel Heuer Fernandes' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# No exact SofaScore match for KBStats player: Max Rosenfelder
#   1. Maximilian Rosenfelder (SofaScore ID 1131337, rating 6.9, similarity 80%)
# Choose a candidate number, or press Enter to skip (score 0):  1
# No exact SofaScore match for KBStats player: Berkay Yilmaz
#   1. Berkay Yılmaz (SofaScore ID 1195724, rating 6.6, similarity 96%)
# Choose a candidate number, or press Enter to skip (score 0):  1
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Abdoul-Karim Coulibaly' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# C:\kickbase project\sofascore_average_rating_score.py:375: UserWarning: Override for 'Salim Amani Musah' has no 'overall' rating; score is 0.
#   scored, review, additions = build_scored_players(players, ratings, overrides)
# Input files
#   KBStats: C:\kickbase project\outputs\kbstats\players\kbstats_players_20260817_194320_+0200.csv
#   SofaScore ratings: C:\kickbase project\outputs\sofascore\player_average_ratings\team_player_average_ratings_2026-08-18_12-55-46_358670+0200.csv
#   Category: overall
#
# Matching summary
#   Exact normalized matches: 141
#   Persisted-override matches: 2
#   Prompted matches: 3
#   Zero-score players: 322
#
# Name-match review (non-exact rows)
#                  kbstats_name        status sofascore_player_name  \
# 2                Sven Ulreich  zero_unrated                   NaN
# 4                Serge Gnabry  zero_unrated                   NaN
# 5    Dayotchanculle Upamecano  zero_unrated                   NaN
# 10                Jonas Urbig  zero_unrated                   NaN
# 17                 Harry Kane  zero_unrated                   NaN
# ..                        ...           ...                   ...
# 453          Éric Dina Ebimbe  zero_unrated                   NaN
# 457              Robin Gosens  zero_unrated                   NaN
# 459         Adrian Gantenbein  zero_unrated                   NaN
# 461                Max Grüger  zero_unrated                   NaN
# 466  Johannes Simon Siebeking  zero_unrated                   NaN
#
#      sofascore_player_id  score  similarity
# 2                    NaN    0.0         NaN
# 4                    NaN    0.0         NaN
# 5                    NaN    0.0         NaN
# 10                   NaN    0.0         NaN
# 17                   NaN    0.0         NaN
# ..                   ...    ...         ...
# 453                  NaN    0.0         NaN
# 457                  NaN    0.0         NaN
# 459                  NaN    0.0         NaN
# 461                  NaN    0.0         NaN
# 466                  NaN    0.0         NaN
#
# [327 rows x 6 columns]
# Output: C:\kickbase project\outputs\expected_points\expected_points_20260817_194320_+0200_sofascore_overall_average_rating_20260818_125920_+0200.csv
# Saved 3 confirmed name override(s): C:\kickbase project\data\reference\sofascore_player_name_overrides.csv
